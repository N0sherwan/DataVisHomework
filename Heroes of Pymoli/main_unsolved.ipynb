# %%
import os
import csv
from datetime import datetime

# %%
csvpath1= os.path.join("raw_data", "employee_data1.csv")

# %%
# The State data should be re-written as simple two-letter abbreviations.
# use https://gist.github.com/afhaque/29f0f4f37463c447770517a6c17d08f5

# %%
with open(csvpath1, 'rb') as csvfile:
    csvreader = csv.reader(csvfile, delimiter=",")
##     csvreader = csv.DictReader(csvfile)
    print(csvreader)
    row_index = 0
    for row in csvreader:
        if row_index>0:
            whole_name = row[1]
            whole_name_list = whole_name.split(' ')
            print(whole_name_list)
            first_name =whole_name_list[0]
            last_name  =whole_name_list[1]
            print(row)
            print(whole_name)
            print(whole_name_list)
            print(first_name)
            print(last_name)
            old_DOB =row[2]
            print(old_DOB)
            new_DOB =datetime.strptime(old_DOB, '%Y-%m-%d')
            print(new_DOB)
            format_DOB=new_DOB.strftime('%d/%m/%Y')
            print(format_DOB)
            old_SSN=row[3]
            new_SSN='***-**-' + old_SSN[7:]
            print(new_SSN)
            old_State=row[4]
            print(old_State)
         
        us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
}
          
        row_index = row_index +1
# Out:
# ...
# ['Sarah', 'Simpson']
# ['214', 'Sarah Simpson', '1985-12-04', '282-01-8166', 'Florida']
# Sarah Simpson
# ['Sarah', 'Simpson']
# Sarah
# Simpson
# 1985-12-04
# 1985-12-04 00:00:00
# 04/12/1985
# ***-**-8166
# Florida
# ['Samantha', 'Lara']
# ['15', 'Samantha Lara', '1993-09-08', '848-80-7526', 'Colorado']
# Samantha Lara
# ['Samantha', 'Lara']
# Samantha
# Lara
# 1993-09-08
# 1993-09-08 00:00:00
# 08/09/1993
# ***-**-7526
# Colorado
# ['Stacy', 'Charles']
# ['411', 'Stacy Charles', '1957-12-20', '658-75-8526', 'Pennsylvania']
# Stacy Charles
# ['Stacy', 'Charles']
# Stacy
# Charles
# 1957-12-20
# 1957-12-20 00:00:00
# 20/12/1957
# ***-**-8526
# Pennsylvania
# ['Michelle', 'Roy']
# ['166', 'Michelle Roy', '1978-07-29', '794-25-3944', 'Michigan']
# Michelle Roy
# ['Michelle', 'Roy']
# Michelle
# Roy
# 1978-07-29
# 1978-07-29 00:00:00
# 29/07/1978
# ***-**-3944
# Michigan
# ['Joseph', 'Rogers']
# ['39', 'Joseph Rogers', '1985-03-28', '525-40-3515', 'Minnesota']
# Joseph Rogers
# ...

# %%
# Initialize csv.writer
    csvwriter = csv.writer(csvfile, delimiter=',')

    # Write the first row (column headers)
    csvwriter.writerow(['first column', 'second column', 'thrid column'])
    
    # Write the second row
    csvwriter.writerow(['first column second row', 'second column second row', 'thrid column '])
